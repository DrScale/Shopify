# %%
import pandas as pd

# %%
data = pd.read_csv('2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv')

# %%
data.head(10)
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
# 5         6       58      882           138            1    credit_card
# 6         7       87      915           149            1           cash
# 7         8       22      761           292            2           cash
# 8         9       64      914           266            2          debit
# 9        10       52      788           146            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11
# 5  2017-03-14 15:25:01
# ...

# %%
data['order_amount'].mean()
# Out:
# 3145.128

# %%
data['order_amount'].plot.hist(logy = True, bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# looks like there're a few really big orders that's messing up the average, let's try median instead
data['order_amount'].median()
# Out:
# 284.0

# %%
data['price_per_item'] = data['order_amount']/data['total_items']

# %%
data['price_per_item'].plot.hist(logy = True, bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# there appears to be an outlier
data[data['price_per_item'] > 5000]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 160        161       78      990         25725            1    credit_card
# 490        491       78      936         51450            2          debit
# 493        494       78      983         51450            2           cash
# 511        512       78      967         51450            2           cash
# 617        618       78      760         51450            2           cash
# 691        692       78      878        154350            6          debit
# 1056      1057       78      800         25725            1          debit
# 1193      1194       78      944         25725            1          debit
# 1204      1205       78      970         25725            1    credit_card
# 1259      1260       78      775         77175            3    credit_card
# 1384      1385       78      867         25725            1           cash
# ...

# %%
# shop 78 has been selling the same shoes at a ridiculous price, let's remove it from the set
data_filtered = data[data['shop_id'] != 78]

# %%
data.shape
# Out:
# (5000, 8)

# %%
data_filtered.shape
# Out:
# (4954, 8)

# %%
data_filtered['price_per_item'].plot.hist(logy = True, bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data[(data['price_per_item'] == 352) & (data['user_id'] == 607)]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %%
data[(data['price_per_item'] == 352) & (data['user_id'] == 607)]['order_amount'].sum()
# Out:
# 11968000

# %%
data[data['user_id'] == 607]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %%
# remove purchases made by user with ID 607 from the dataset.
data_filtered = data_filtered[data_filtered['user_id'] != 607]

# %%
data_filtered['order_amount'].mean()
# Out:
# 302.58051448247926

# %% [markdown]
# # The abonormally high AOV is mostly caused by these 2 factors
#
# ## 1. Shop 78 most likely is making mistake when inputting numbers
# Shop 78 most likely mistakenly submitted their price as 25725.
# They are still making sales to rational customers who are buying shoes at other shops as well. Thus, they most likely paid the usual price and the mistake is merely made at the database level
#
# ## 2. Shop 42 and shopper 607's activity arises suspicion on money laundering
# It seems like not only does shop 42 sells their shoes at a price substantially higher than the market price, there are also automated purchases made at 4 o'clock on various dates by shopper with id 607, who does not shop anywhere else.
# The amount spent totals to over 11 million dollars and all purchases are made via credit card.
# People need to look into this.
#
# ## With these abnormalities removed, the mean is decreased to just over 300 dollars, making AOV viable.
# However, I still believe AOV should be presented together with other measurements such as the median, since similar mistakes can be made easily.

# %% [markdown]
# ## Without further information, these are the matrics I would report based on this database
# The matrics are calculated using a filtered version of the database with the 2 abnormalities I mentioned above removed.

# %%
f"The median for amount per order is {round(data_filtered['order_amount'].median(), 2)}"
# Out:
# 'The median for amount per order is 284.0'

# %%
f"The mean for amount per order is {round(data_filtered['order_amount'].mean(), 2)}"
# Out:
# 'The mean for amount per order is 302.58'

# %%
f"The median for items per order is {data_filtered['total_items'].median()}"
# Out:
# 'The median for items per order is 2.0'

# %%
f"The mean for items per order is {round(data_filtered['total_items'].mean(), 2)}"
# Out:
# 'The mean for items per order is 1.99'

# %%
f"The max amount of a single order is {round(data_filtered['order_amount'].max(), 2)}, and the min amount of a single order is {round(data_filtered['order_amount'].min(), 2)}."
# Out:
# 'The max amount of a single order is 1760, and the min amount of a single order is 90.'

# %%
f"The max number of items per single order is {round(data_filtered['total_items'].max(), 2)}, and the min number of items per single order is {round(data_filtered['total_items'].min(), 2)}."
# Out:
# 'The max number of items per single order is 8, and the min number of items per single order is 1.'

# %% [markdown]
# # Question 2 -- SQL Queries

# %%
# 1. How many orders were shipped by Speedy Express in total?
SELECT count(*) FROM Orders natural join Shippers
WHERE ShipperName = "Speedy Express";

'''52 orders were shipped by Speedy Express'''

# 2. What is the last name of the employee with the most orders?
SELECT max(orders), LastName FROM 
    (SELECT sum(EmployeeID) as orders, lastName 
    FROM Orders natural join Employees
    GROUP BY EmployeeID);
    
'''Callahan is the last name, they made 216 orders'''
    

    
# 3. What product was ordered the most by customers in Germany?
SELECT productID, max(Quantity) FROM
    (SELECT productID, sum(Quantity) as Quantity FROM OrderDetails natural JOIN Orders natural JOIN Customers
    WHERE Country = "Germany"
    GROUP BY ProductID);
    
'''Product 40 was most ordered by customers in Germany. The amount ordered was 160 units.'''
